# %% [markdown]
# # 04 - Baseline Model

# %%
import pandas as pd
from src.models.train_baseline import train_baseline_classifier

TRAIN_PATH = "data/raw/train.csv"
TARGET = "target"
df = pd.read_csv(TRAIN_PATH)
artifacts = train_baseline_classifier(df, TARGET)
artifacts.result

# %% [markdown]
# ## Next steps
# - Error analysis
# - Feature ablation
# - CV chiến lược theo rule
