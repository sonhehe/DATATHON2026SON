# %% [markdown]
# # 03 - Feature Ideas
#
# Chuyển insight từ EDA thành giả thuyết feature có kiểm soát leakage.

# %%
import pandas as pd
from src.models.explain import summarize_feature_hypotheses

ideas = summarize_feature_hypotheses()
ideas

# %%
# Ví dụ thêm ý tưởng
ideas.loc[len(ideas)] = {
    "feature_name": "is_zero__amount",
    "feature_type": "binary_flag",
    "hypothesis": "Các bản ghi amount=0 có hành vi khác rõ rệt",
    "evidence": "EDA: zero-inflated > 80% và target rate khác biệt",
    "leakage_risk": "low",
    "priority": "high",
    "owner": "you",
    "status": "proposed",
}
ideas
